# %% [markdown]
# # Project 2: Learning from Imbalanced Datasets (Supervised and Unsupervised Learning)
# ## CE888
# ### Arely Aceves Compean
# ### 1900968

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from imblearn.over_sampling import RandomOverSampler
from imblearn.under_sampling import RandomUnderSampler
from sklearn.model_selection import StratifiedKFold
from utils import *
os.environ['KAGGLE_USERNAME'] = "arelya" # username from the json file
os.environ['KAGGLE_KEY'] = "e276ea403eb01cd7fef5f90fdbcf34db" # key from the json file

# %% [markdown]
# # Credit Card Dataset

# %% [markdown]
# ## Download the dataset from kaggle

# %% [markdown]
# https://www.kaggle.com/mlg-ulb/creditcardfraud

# %%
# !kaggle datasets download -d mlg-ulb/creditcardfraud
# Out:
# creditcardfraud.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
df_creditcard = pd.read_csv("creditcardfraud.zip", compression='zip', header=0, sep=',', quotechar='"', encoding='utf-8')
df_creditcard.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %% [markdown]
# ## Imbalance Correction (To fit specifications)

# %% [markdown]
# ### Original imbalance

# %%
print('No Frauds ', round(df_creditcard['Class'].value_counts()[0]/len(df_creditcard) * 100,2), '% of the dataset (', df_creditcard['Class'].value_counts()[0], ')', sep='')
print('Frauds ', round(df_creditcard['Class'].value_counts()[1]/len(df_creditcard) * 100,2), '% of the dataset (', df_creditcard['Class'].value_counts()[1], ')', sep='')
# Out:
# No Frauds 99.83% of the dataset (284315)
# Frauds 0.17% of the dataset (492)

# %% [markdown]
# ### New Imbalance

# %% [markdown]
# 275000 'non fraudulent' transactions were dropped to achieve a 90% - 95% imbalance

# %%
df_creditcard = pd.concat([df_creditcard[df_creditcard['Class'] == 1], df_creditcard[df_creditcard['Class'] == 0].drop(df_creditcard[df_creditcard['Class'] == 0].index[1:275000])])                   
print('No Frauds ', round(df_creditcard['Class'].value_counts()[0]/len(df_creditcard) * 100,2), '% of the dataset (', df_creditcard['Class'].value_counts()[0], ')', sep='')
print('Frauds ', round(df_creditcard['Class'].value_counts()[1]/len(df_creditcard) * 100,2), '% of the dataset (', df_creditcard['Class'].value_counts()[1], ')', sep='')
# Out:
# No Frauds 94.98% of the dataset (9316)
# Frauds 5.02% of the dataset (492)

# %% [markdown]
# ## Inspecting the Dataset

# %% [markdown]
# This dataset contains only quantitative variables

# %%
sns.countplot('Class', data=df_creditcard)
plt.title('Class Distributions \n (0: no fraud || 1: fraud)', fontsize=14)
# Out:
# Text(0.5, 1.0, 'Class Distributions \n (0: no fraud || 1: fraud)')

# %%
for col in df_creditcard.columns:
    if col != 'Class':
        sns.distplot(df_creditcard[col])
        plt.title(col.upper(), fontsize=14)
        plt.show()

# %% [markdown]
# ## Transform Dataframe into Numpy Array

# %%
X = np.array(df_creditcard.drop('Class', axis=1))
y = np.array(df_creditcard['Class'])

# %% [markdown]
# ## Classification Methods

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

dt_clf = DecisionTreeClassifier(random_state=0, max_depth=3)
rf_clf = RandomForestClassifier(random_state=0, n_estimators=1000, max_depth=3)

# %% [markdown]
# ### Baseline

# %% [markdown]
# #### Decision Tree Classifier

# %%
dt_baseline = scoring_baseline(X, y, dt_clf, 'Decision Tree', 'f1')
# Out:
# SCORES FOR MODEL DECISION TREE:
# ACCURACY: 0.9195 +/- 0.2335
# PRECISION: 0.9004 +/- 0.2802
# RECALL: 0.9571 +/- 0.1286
# F1: 0.8813 +/- 0.2677

# %% [markdown]
# #### Radom Forest Classifier

# %%
rf_baseline = scoring_baseline(X, y, rf_clf, 'Random Forest Tree', 'f1')
# Out:
# SCORES FOR MODEL RANDOM FOREST TREE:
# ACCURACY: 0.9929 +/- 0.0044
# PRECISION: 0.9866 +/- 0.0271
# RECALL: 0.8716 +/- 0.0997
# F1: 0.9214 +/- 0.0534

# %% [markdown]
# ### Typical Methods: Resampling

# %% [markdown]
# #### Oversample

# %% [markdown]
# Using random oversampling to balance dataset.
# Only oversampling train sample to avoid data bleeding.

# %%
n = 10 # Number of splits
splitter = StratifiedKFold(n_splits=n) # Stratified Splitter
y_predicted = []
y_true = []

for train_index, test_index in splitter.split(X, y):
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]
    
    oversample = RandomOverSampler(sampling_strategy='minority')
    X_over, y_over = oversample.fit_resample(X_train, y_train)
    
    rf = RandomForestClassifier(random_state=0, n_estimators=1000, max_depth=3)
    rf.fit(X_over, y_over)
    y_predicted.append(rf.predict(X_test))
    y_true.append(y_test)
    
rf_over = scoring(y_true, y_predicted, 'f1')
# Out:
# SCORES FOR MODEL:
# ACCURACY: 0.9827 +/- 0.0436
# PRECISION: 0.9852 +/- 0.0367
# RECALL: 0.9827 +/- 0.0436
# F1: 0.9790 +/- 0.0548

# %% [markdown]
# #### Undersample

# %% [markdown]
# Undersampling using Random Undersampling to remove examples from the majority class.

# %%
n = 10 # Number of splits
splitter = StratifiedKFold(n_splits=n) # Stratified Splitter
y_predicted = []
y_true = []

for train_index, test_index in splitter.split(X, y):
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]
    
    undersample = RandomUnderSampler(sampling_strategy='majority')
    X_under, y_under = undersample.fit_resample(X_train, y_train)
    
    rf = RandomForestClassifier(random_state=0, n_estimators=1000, max_depth=3)
    rf.fit(X_under, y_under)
    y_predicted.append(rf.predict(X_test))
    y_true.append(y_test)
    
rf_under = scoring(y_true, y_predicted, 'f1')
# Out:
# SCORES FOR MODEL:
# ACCURACY: 0.9928 +/- 0.0155
# PRECISION: 0.9932 +/- 0.0146
# RECALL: 0.9928 +/- 0.0155
# F1: 0.9920 +/- 0.0179

# %% [markdown]
# ### New Method

# %% [markdown]
# A combination of supervised and unsupervised learning.
#
# 1 - Unsupervised clustering selection using K-Means to create clusters and Elbow and Silhouette methods to identify the possible optimal K and F1 score to choose in case these disagree.
#
# 2 - Training of a Random Forest Classifier per cluster (where needed).
#
# 3 - Predicting a cluster using the chosen clustering and a label using the classifier of its assigned cluster.

# %%
n = 10
fold = 1
splitter = StratifiedKFold(n_splits=n, random_state=0)
y_predicted_list = []
y_true_list = []

for train_index, test_index in splitter.split(X, y):
    print('\nFOLD:', fold)
    fold += 1
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]
    
    k, chosen_km = silhouette_elbow_cluster_selection(X_train, y_train)
    
    clfs = cluster_training(X_train, y_train, k, chosen_km)
    
    y_predicted_list.append(cluster_testing(X_test, chosen_km, clfs))
    
    y_true_list.append(y_test)
# Out:
# FOLD: 1
# C:\Users\Arely\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:296: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   FutureWarning
# Please enter the selected number of clusters for the silhouette graph:
# 2
# Please enter the selected number of clusters for the elbow graph:
# 4
# Best performing clustering f1-score is: 0.9861152769651362 for n_clusters = 2
#
# FOLD: 2
# Please enter the selected number of clusters for the silhouette graph:
# 2
# Please enter the selected number of clusters for the elbow graph:
# 3
# Best performing clustering f1-score is: 0.9669093775621291 for n_clusters = 3
#
# FOLD: 3
# Please enter the selected number of clusters for the silhouette graph:
# 2
# Please enter the selected number of clusters for the elbow graph:
# 4
# Best performing clustering f1-score is: 0.9858124492646044 for n_clusters = 2
#
# FOLD: 4
# Please enter the selected number of clusters for the silhouette graph:
# 2
# Please enter the selected number of clusters for the elbow graph:
# 4
# Best performing clustering f1-score is: 0.9858124492646044 for n_clusters = 2
#
# FOLD: 5
# Please enter the selected number of clusters for the silhouette graph:
# 2
# Please enter the selected number of clusters for the elbow graph:
# 5
# Best performing clustering f1-score is: 0.9858124492646044 for n_clusters = 2
#
# FOLD: 6
# Please enter the selected number of clusters for the silhouette graph:
# 2
# Please enter the selected number of clusters for the elbow graph:
# 5
# Best performing clustering f1-score is: 0.9854467952759205 for n_clusters = 2
#
# FOLD: 7
# Please enter the selected number of clusters for the silhouette graph:
# 2
# Please enter the selected number of clusters for the elbow graph:
# 5
# Best performing clustering f1-score is: 0.9852652083173985 for n_clusters = 2
#
# FOLD: 8
# Please enter the selected number of clusters for the silhouette graph:
# 2
# Please enter the selected number of clusters for the elbow graph:
# 4
# Best performing clustering f1-score is: 0.9894415825631744 for n_clusters = 2
#
# FOLD: 9
# Please enter the selected number of clusters for the silhouette graph:
# 2
# Please enter the selected number of clusters for the elbow graph:
# 4
# Best performing clustering f1-score is: 0.9905420831676577 for n_clusters = 2
#
# FOLD: 10
# Please enter the selected number of clusters for the silhouette graph:
# 2
# Please enter the selected number of clusters for the elbow graph:
# 5
# Best performing clustering f1-score is: 0.9905420831676577 for n_clusters = 2

# %%
scores = scoring(y_true_list, y_predicted_list, 'f1')
# Out:
# SCORES FOR MODEL:
# ACCURACY: 0.9913 +/- 0.0158
# PRECISION: 0.9971 +/- 0.0039
# RECALL: 0.9913 +/- 0.0158
# F1: 0.9940 +/- 0.0092

# %% [markdown]
# ## Model Comparison

# %%
fig, ax = plt.subplots()
labels = ["Baseline DT", "Baseline RF", "Oversampled", "Downsampled", "New Method"]
ax.boxplot([dt_baseline, rf_baseline, rf_over, rf_under, scores])
ax.set_xticklabels(labels, rotation=45)
plt.show()

# %%
titles = ["Baseline DT", "Baseline RF", "Oversampled", "Downsampled", "New Method"]
plots = [dt_baseline, rf_baseline, rf_over, rf_under, scores]

for plot in range(5):
    boxplot(plots[plot], titles[plot])

# %%
o_titles = ["Baseline DT", "Baseline RF", "Oversampled", "Downsampled", "New Method"]
o_plots = [dt_baseline, rf_baseline, rf_over, rf_under, scores]

for plot in range(5):
    noOutliers_boxplot(o_plots[plot], o_titles[plot])
